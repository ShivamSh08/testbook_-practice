# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# Context Managers & Iterators

# %%
with open("hello.txt", mode="w") as file:
    file.write("Hello, World!")

# %% [markdown]
# [link text](https://)Iterators

# %%
mytuple = ("apple", "banana", "cherry")
myit = iter(mytuple)

print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# Can not Divide by 0
# Code executed without error
